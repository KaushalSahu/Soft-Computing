# %%
import numpy as np
from ipywidgets import interact
from bokeh.plotting import figure, show, output_notebook
from bokeh.layouts import gridplot
from bokeh.io import push_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="0f0b25dd-e0d7-410c-9069-5093aa1e7e13">Loading BokehJS ...</span>
#     </div>

# %%
def local_regression(x0, X, Y, tau):
    # add bias term
    x0 = np.r_[1, x0]
    X = np.c_[np.ones(len(X)), X]
    
    # fit model: normal equations with kernel
    xw = X.T * radial_kernel(x0, X, tau)
    beta = np.linalg.pinv(xw @ X) @ xw @ Y
    
    # predict value
    return x0 @ beta

# %%
def radial_kernel(x0, X, tau):
    return np.exp(np.sum((X - x0) ** 2, axis=1) / (-2 * tau * tau))

# %%
n = 1000

# generate dataset
X = np.linspace(-3, 3, num=n)
Y = np.log(np.abs(X ** 2 - 1) + .5)

# jitter X
X += np.random.normal(scale=.1, size=n)

# %%
def plot_lwr(tau):
    # prediction
    domain = np.linspace(-3, 3, num=300)
    prediction = [local_regression(x0, X, Y, tau) for x0 in domain]

    plot = figure(plot_width=400, plot_height=400)
    plot.title.text = 'tau=%g' % tau
    plot.scatter(X, Y, alpha=.3)
    plot.line(domain, prediction, line_width=2, color='red')
    
    return plot

# %%
show(gridplot([
    [plot_lwr(10.), plot_lwr(1.)],
    [plot_lwr(0.1), plot_lwr(0.01)]
]))
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="a92ec5f0-0e5e-4681-b0fd-32c902212007"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("a92ec5f0-0e5e-4681-b0fd-32c902212007");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("a92ec5f0-0e5e-4681-b0fd-32c902212007");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'a92ec5f0-0e5e-4681-b0fd-32c902212007' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"a4c54abe-681b-4321-a8c5-f769dc97ca17":{"roots":{"references":[{"attributes":{},"id":"5b8095db-43ed-4ff4-8309-524387007218","type":"BasicTickFormatter"},{"attributes":{},"id":"6ea1e13b-78bb-4ea0-842a-a9185a9775b4","type":"HelpTool"},{"attributes":{},"id":"ae203ea6-fb9c-4086-adc2-5f01c79cd462","type":"ResetTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"2ccbf34a-fa75-4ffc-8a0b-8487d96bf016","type":"PanTool"},{"id":"3817a200-1544-4509-992e-3135cfe84131","type":"WheelZoomTool"},{"id":"830cc9c8-ffc2-403d-9a7f-1c9930b28436","type":"BoxZoomTool"},{"id":"28674a8e-7fdc-4d66-aef2-4b6dc602bac0","type":"SaveTool"},{"id":"d384eb0d-b55f-44c3-8d10-a2f97e0f37e1","type":"ResetTool"},{"id":"0ac2a6d2-b4a7-4b3e-9c73-8ab78eab0733","type":"HelpTool"}]},"id":"2609398d-b90a-45a4-81bb-51d8d0f7b640","type":"Toolbar"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"7d735844-0bf4-4c44-a6f1-f41ef7909631","type":"Line"},{"attributes":{"plot":{"id":"e6db1b6c-fcb4-41e2-9230-6f1d904fba88","subtype":"Figure","type":"Plot"},"ticker":{"id":"4b8cbf9f-a5b5-4278-b656-d980b9f71a61","type":"BasicTicker"}},"id":"c10b3110-7863-4a6d-bbc1-f16ea4e522ed","type":"Grid"},{"attributes":{"source":{"id":"4e09a9b6-89c2-403d-82c0-010c522b8ae3","type":"ColumnDataSource"}},"id":"17f3b25e-eee1-4264-98df-ac8d9544b2ec","type":"CDSView"},{"attributes":{"below":[{"id":"6ea063b0-2950-480b-9350-0eb11d126e51","type":"LinearAxis"}],"left":[{"id":"c32fd4fe-66de-414a-b30d-c57e8a2d2771","type":"LinearAxis"}],"plot_height":400,"plot_width":400,"renderers":[{"id":"6ea063b0-2950-480b-9350-0eb11d126e51","type":"LinearAxis"},{"id":"c10b3110-7863-4a6d-bbc1-f16ea4e522ed","type":"Grid"},{"id":"c32fd4fe-66de-414a-b30d-c57e8a2d2771","type":"LinearAxis"},{"id":"cd17d567-9e0e-4d1f-85df-73fa8aa7e9bc","type":"Grid"},{"id":"b50110cf-afd4-4cb3-9576-b289be28195a","type":"BoxAnnotation"},{"id":"54397934-4ef4-492d-b84b-22c628309042","type":"GlyphRenderer"},{"id":"e0012f93-14f5-49cd-a4a5-7dc2d720682a","type":"GlyphRenderer"}],"title":{"id":"b1246b66-36a3-4b6f-8296-9655ffba5d85","type":"Title"},"toolbar":{"id":"2609398d-b90a-45a4-81bb-51d8d0f7b640","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"466000cf-aecc-4c80-8aa6-877fa9bbc965","type":"DataRange1d"},"x_scale":{"id":"516bd600-c199-42c5-aed2-186f9e7c2106","type":"LinearScale"},"y_range":{"id":"de1e93f1-6de2-4dca-96b0-e813c71e0bab","type":"DataRange1d"},"y_scale":{"id":"0267cd30-8ba6-4601-a62e-f5165bab938a","type":"LinearScale"}},"id":"e6db1b6c-fcb4-41e2-9230-6f1d904fba88","subtype":"Figure","type":"Plot"},{"attributes":{"source":{"id":"0d5d2688-cdbc-4946-8005-3e55e07af476","type":"ColumnDataSource"}},"id":"cf035066-0334-4786-8ef4-61a1c82cce40","type":"CDSView"},{"attributes":{},"id":"516bd600-c199-42c5-aed2-186f9e7c2106","type":"LinearScale"},{"attributes":{},"id":"437dcae7-0723-4664-98c2-cf9cd3e2c25c","type":"BasicTickFormatter"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[300]},"y":[2.211571058006374,2.1898714553763576,2.1681408505588955,2.1463821957153097,2.1245985061493506,2.102792859296825,2.0809683936258976,2.0591283074468905,2.0372758576316214,2.01541435824139,1.9935471790639085,1.971677744058756,1.9498095297115599,1.927946063297461,1.9060909210539005,1.8842477262638122,1.8624201472496893,1.8406118952799,1.81882672238815,1.7970684191078243,1.7753408121225769,1.7536477618351807,1.7319931598565148,1.7103809264170757,1.688815007703348,1.6672993731217616,1.6458380124929823,1.6244349331797943,1.6030941571516175,1.581819717989334,1.560615657833967,1.5394860242831339,1.518434867239367,1.4974662357144592,1.476584174594409,1.4557927213694148,1.4350959028338472,1.4144977317610306,1.3940022035580117,1.3736132929054523,1.3533349503881462,1.3331710991215209,1.3131256313798416,1.29320240 ...

# %%
def interactive_update(tau):
    model.data_source.data['y'] = [local_regression(x0, X, Y, tau) for x0 in domain]
    push_notebook()

domain = np.linspace(-3, 3, num=100)
prediction = [local_regression(x0, X, Y, 1.) for x0 in domain]

plot = figure()
plot.scatter(X, Y, alpha=.3)
model = plot.line(domain, prediction, line_width=2, color='red')
show(plot, notebook_handle=True)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="556d0e30-c7a1-4fba-87c9-c1a96a2ed0d0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("556d0e30-c7a1-4fba-87c9-c1a96a2ed0d0");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("556d0e30-c7a1-4fba-87c9-c1a96a2ed0d0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '556d0e30-c7a1-4fba-87c9-c1a96a2ed0d0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"cabca4a8-c39c-450f-9310-a00b9e46a424":{"roots":{"references":[{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"b46370a1-979f-4d0d-8bb5-d328d2a3f142","type":"BoxAnnotation"},{"attributes":{},"id":"5ae70717-6480-49d2-837c-bd43af8afcda","type":"ResetTool"},{"attributes":{},"id":"8d7a1fdd-84bb-4350-aab8-fd702c4c7385","type":"HelpTool"},{"attributes":{},"id":"e7f81468-7600-4b24-9ce8-3ebe8d50c928","type":"BasicTickFormatter"},{"attributes":{"formatter":{"id":"06afef58-8c3a-4533-b962-d463b470adc6","type":"BasicTickFormatter"},"plot":{"id":"1dc94a01-8688-4e39-82ef-a7e5370013b6","subtype":"Figure","type":"Plot"},"ticker":{"id":"69e71d17-9043-4e20-8eae-d6f513ec99fd","type":"BasicTicker"}},"id":"1d497b37-532a-4fd0-8b73-a574545ec33b","type":"LinearAxis"},{"attributes":{"plot":null,"text":""},"id":"e12bf82e-21c9-4a85-a2b7-34a6a2cc6da3","type":"Title"},{"attributes":{},"id":"06afef58-8c3a-4533-b962-d463b470adc6","type":"BasicTickFormatter"},{"attributes":{"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":2},"x":{"field":"x"},"y":{"field":"y"}},"id":"f0b4b1cb-9b72-42dc-9497-e6fd7a1fc6d5","type":"Line"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"x":{"field":"x"},"y":{"field":"y"}},"id":"8ce27400-8b2c-458a-9a6f-0f405a9c5af1","type":"Circle"},{"attributes":{"data_source":{"id":"4e53a0e1-b3d6-4b51-8ea7-67368dafc87b","type":"ColumnDataSource"},"glyph":{"id":"dafaf8ab-f602-4e5a-9687-7be0887fbfc5","type":"Line"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"f0b4b1cb-9b72-42dc-9497-e6fd7a1fc6d5","type":"Line"},"selection_glyph":null,"view":{"id":"65a236d3-d3dc-438b-a24b-e9070bfb9c83","type":"CDSView"}},"id":"726a7b1d-a5d8-4da3-b044-d404c4106ee4","type":"GlyphRenderer"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"f026bc09-486b-40a2-b300-4a3ed169f9c8","type":"PanTool"},{"id":"b9a7c2db-9e18-43a6-a9ee-fedb307fd20a","type":"WheelZoomTool"},{"id":"34c1c4ee-7552-4915-9dee-27003df93b1c","type":"BoxZoomTool"},{"id":"41b2b345-e32b-4655-92ba-98e447680b06","type":"SaveTool"},{"id":"5ae70717-6480-49d2-837c-bd43af8afcda","type":"ResetTool"},{"id":"8d7a1fdd-84bb-4350-aab8-fd702c4c7385","type":"HelpTool"}]},"id":"fb6c8714-c51a-42ce-94c9-432f68acfa5e","type":"Toolbar"},{"attributes":{"source":{"id":"4e53a0e1-b3d6-4b51-8ea7-67368dafc87b","type":"ColumnDataSource"}},"id":"65a236d3-d3dc-438b-a24b-e9070bfb9c83","type":"CDSView"},{"attributes":{"callback":null},"id":"58089e74-51cc-4cc1-9796-91cd9dc350f2","type":"DataRange1d"},{"attributes":{"callback":null,"column_names":["x","y"],"data":{"x":{"__ndarray__":"...","dtype":"float64","shape":[1000]},"y":{"__ndarray__":"...","dtype":"float64","shape":[1000]}}},"id":"8e8c4364-95dd-4e54-8e9c-5ce124e64395","type":"ColumnDataSource"},{"attributes":{},"id":"69e71d17-9043-4e20-8eae-d6f513ec99fd","type":"BasicTicker"},{"attributes":{"below":[{"id":"81c64b4f-6d7d-48ad-a315-ba7d260ea829","type":"LinearAxis"}],"left":[{"id":"1d497b37-532a-4fd0-8b73-a574545ec33b","type":"LinearAxis"}],"renderers":[{"id":"81c64b4f-6d7d-48ad-a315-ba7d260ea829","type":"LinearAxis"},{"id":"290824f5-b728-45c7-9e01-25a50ec936a5","type":"Grid"},{"id":"1d497b37-532a-4fd0-8b73-a574545ec33b","type":"LinearAxis"},{"id":"9f3d76c0-e8f5-4a6f-810f-0b86c477fc68","type":"Grid"},{"id":"b46370a1-979f-4d0d-8bb5-d328d2a3f142","type":"BoxAnnotation"},{"id":"e03d80cf-87c0-430b-a0c7-d7fc46b0c052","type":"GlyphRenderer"},{"id":"726a7b1d-a5d8-4da3-b044-d404c4106ee4","type":"GlyphRenderer"}],"title":{"id":"e12bf82e-21c9-4a85-a2b7-34a6a2cc6da3","type":"Title"},"to ...

# %%
interact(interactive_update, tau=(0.01, 3., 0.01))
# Out:
# A Jupyter Widget
# <function __main__.interactive_update>
